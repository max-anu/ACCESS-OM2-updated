# %% [markdown]
# # SSS Biases

# %%
# %matplotlib inline

import pandas as pd
import cosima_cookbook as cc
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import IPython.display
import cmocean as cm
import cartopy.crs as ccrs
import cartopy.feature as cft
from dask.distributed import Client, progress


import sys, os

os.chdir(os.path.join(os.getcwd(), "ACCESS-OM2-updated/figures/temperature_biases"))
sys.path.append(os.path.join(os.getcwd(), '..'))  # so we can import ../exptdata
import exptdata
print('Available exptdata keys: ', [k for k in exptdata.exptdict.keys()])
# Out:
# Available exptdata keys:  ['1deg', '025deg', '01deg']

# %%
# use common start and end dates for all runs
tstart = exptdata.clim_tstart
tend = exptdata.clim_tend

# %%
figdir = ''
def savefigure(fname):
    plt.savefig(os.path.join(figdir, fname+'.png'),dpi=300, bbox_inches="tight")  # comment out to disable saving
    plt.savefig(os.path.join(figdir, fname+'.pdf'),dpi=300, bbox_inches="tight")  # comment out to disable saving
    return

# %%
client = Client("tcp://10.6.46.29:8786")
client
# Out:
# <Client: 'tcp://10.6.46.29:8786' processes=2 threads=48, memory=188.56 GiB>

# %%
session = cc.database.create_session()

# %%
ekey='1deg'
expt = exptdata.exptdict[ekey]['expt']
n_files = exptdata.exptdict[ekey]['n_files']
time_units = exptdata.exptdict[ekey]['time_units']
offset = exptdata.exptdict[ekey]['offset']

darray = cc.querying.getvar(session=session, expt=expt, variable='salt', chunks={'st_ocean': None}, n=n_files, frequency='1 monthly')
if offset:
    td = pd.Timedelta(days=offset)
    darray = darray.assign_coords(time=darray.time + td)
surface_salt_10 = darray.isel(st_ocean=0).sel(time=slice(tstart,tend)).mean('time')
darray = cc.querying.getvar(session=session, expt='woa13/10_KDS50', variable='salt')
salt_WOA13_10 = darray.isel(ZT=0).mean('time')
#salt_WOA13_10 = cc.get_nc_variable('woa13/10_KDS50', 'ocean_salt_salt.res.nc', 'salt').isel(ZT=0).mean('time')

salt_anom_10 = surface_salt_10 - salt_WOA13_10.values
salt_anom_10.load()

IPython.display.clear_output()

salt_anom_10.plot()
# Out:
# ---------------------------------------------------------------------------
# VariableNotFoundError                     Traceback (most recent call last)
# Cell In[6], line 12
#      10     darray = darray.assign_coords(time=darray.time + td)
#      11 surface_salt_10 = darray.isel(st_ocean=0).sel(time=slice(tstart,tend)).mean('time')
# ---> 12 darray = cc.querying.getvar(session=session, expt='woa13/10_KDS50', variable='salt')
#      13 salt_WOA13_10 = darray.isel(ZT=0).mean('time')
#      14 #salt_WOA13_10 = cc.get_nc_variable('woa13/10_KDS50', 'ocean_salt_salt.res.nc', 'salt').isel(ZT=0).mean('time')
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/cosima_cookbook/querying.py:334, in getvar(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique, return_dataset, **kwargs)
#     331 if attrs_unique is None:
#     332     attrs_unique = {"cell_methods": "time: mean"}
# --> 334 ncfiles = _ncfiles_for_variable(
#     335     expt,
#     336     variable,
#     337     session,
#     338     ncfile,
#     339     start_time,
#     340     end_time,
#     341     n,
#     342     frequency,
#     343     attrs,
#     344     attrs_unique,
#     345 )
#     347 variables = [variable]
#     348 if return_dataset:
#     349     # we know at least one variable was returned, so we can index ncfiles
#     350     # ask for the extra variables associated with cell_methods, etc.
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/cosima_cookbook/querying.py:505, in _ncfiles_for_variable(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique)
#     503 # ensure we actually got a result
#     504 if not ncfiles:
# --> 505     raise VariableNotFoundError(
#     506         "No files were found containing '{}' in the '{}' experiment".format(
#     507             variable, expt
#     508         )
#     509     )
#     511 # check whether the results are unique
#     512 for attr in attrs_unique:
#
# VariableNotFoundError: No files were found containing 'salt' in the 'woa13/10_KDS50' experiment

# %%
ekey='025deg'
expt = exptdata.exptdict[ekey]['expt']
n_files = exptdata.exptdict[ekey]['n_files']
time_units = exptdata.exptdict[ekey]['time_units']
offset = exptdata.exptdict[ekey]['offset']
darray = cc.querying.getvar(session=session, expt=expt, variable='salt', chunks={'st_ocean': None}, n=n_files, frequency='1 monthly')
if offset:
    td = pd.Timedelta(days=offset)
    darray = darray.assign_coords(time=darray.time + td)
surface_salt_025 = darray.isel(st_ocean=0).sel(time=slice(tstart,tend)).mean('time')
darray = cc.querying.getvar(session=session, expt='woa13/025_KDS50', variable='salt')
salt_WOA13_025 = darray.isel(ZT=0).mean('time')
salt_anom_025 = surface_salt_025 - salt_WOA13_025.values 

salt_anom_025.load()

IPython.display.clear_output()

salt_anom_025.plot()
# Out:
# ---------------------------------------------------------------------------
# VariableNotFoundError                     Traceback (most recent call last)
# Cell In[8], line 11
#       9     darray = darray.assign_coords(time=darray.time + td)
#      10 surface_salt_025 = darray.isel(st_ocean=0).sel(time=slice(tstart,tend)).mean('time')
# ---> 11 darray = cc.querying.getvar(session=session, expt='woa13/025_KDS50', variable='salt')
#      12 salt_WOA13_025 = darray.isel(ZT=0).mean('time')
#      13 salt_anom_025 = surface_salt_025 - salt_WOA13_025.values
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/cosima_cookbook/querying.py:334, in getvar(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique, return_dataset, **kwargs)
#     331 if attrs_unique is None:
#     332     attrs_unique = {"cell_methods": "time: mean"}
# --> 334 ncfiles = _ncfiles_for_variable(
#     335     expt,
#     336     variable,
#     337     session,
#     338     ncfile,
#     339     start_time,
#     340     end_time,
#     341     n,
#     342     frequency,
#     343     attrs,
#     344     attrs_unique,
#     345 )
#     347 variables = [variable]
#     348 if return_dataset:
#     349     # we know at least one variable was returned, so we can index ncfiles
#     350     # ask for the extra variables associated with cell_methods, etc.
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/cosima_cookbook/querying.py:505, in _ncfiles_for_variable(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique)
#     503 # ensure we actually got a result
#     504 if not ncfiles:
# --> 505     raise VariableNotFoundError(
#     506         "No files were found containing '{}' in the '{}' experiment".format(
#     507             variable, expt
#     508         )
#     509     )
#     511 # check whether the results are unique
#     512 for attr in attrs_unique:
#
# VariableNotFoundError: No files were found containing 'salt' in the 'woa13/025_KDS50' experiment

# %%
ekey='01deg'
expt = exptdata.exptdict[ekey]['expt']
n_files = exptdata.exptdict[ekey]['n_files']
time_units = exptdata.exptdict[ekey]['time_units']
offset = exptdata.exptdict[ekey]['offset']
darray = cc.querying.getvar(session=session, expt=expt, variable='salt', chunks={'st_ocean': None}, n=n_files)
if offset:
    td = pd.Timedelta(days=offset)
    darray = darray.assign_coords(time=darray.time + td)
surface_salt_01 = darray.isel(st_ocean=0).sel(time=slice(tstart,tend)).mean('time')
darray = cc.querying.getvar(session=session, expt='woa13/01', variable='salt')
salt_WOA13_01 = darray.isel(ZT=0).mean('time')
salt_anom_01 = surface_salt_01 - salt_WOA13_01.values
salt_anom_01.load()
IPython.display.clear_output()

salt_anom_01.plot()
# Out:
# ---------------------------------------------------------------------------
# VariableNotFoundError                     Traceback (most recent call last)
# Cell In[9], line 11
#       9     darray = darray.assign_coords(time=darray.time + td)
#      10 surface_salt_01 = darray.isel(st_ocean=0).sel(time=slice(tstart,tend)).mean('time')
# ---> 11 darray = cc.querying.getvar(session=session, expt='woa13/01', variable='salt')
#      12 salt_WOA13_01 = darray.isel(ZT=0).mean('time')
#      13 salt_anom_01 = surface_salt_01 - salt_WOA13_01.values
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/cosima_cookbook/querying.py:334, in getvar(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique, return_dataset, **kwargs)
#     331 if attrs_unique is None:
#     332     attrs_unique = {"cell_methods": "time: mean"}
# --> 334 ncfiles = _ncfiles_for_variable(
#     335     expt,
#     336     variable,
#     337     session,
#     338     ncfile,
#     339     start_time,
#     340     end_time,
#     341     n,
#     342     frequency,
#     343     attrs,
#     344     attrs_unique,
#     345 )
#     347 variables = [variable]
#     348 if return_dataset:
#     349     # we know at least one variable was returned, so we can index ncfiles
#     350     # ask for the extra variables associated with cell_methods, etc.
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.07/lib/python3.10/site-packages/cosima_cookbook/querying.py:505, in _ncfiles_for_variable(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique)
#     503 # ensure we actually got a result
#     504 if not ncfiles:
# --> 505     raise VariableNotFoundError(
#     506         "No files were found containing '{}' in the '{}' experiment".format(
#     507             variable, expt
#     508         )
#     509     )
#     511 # check whether the results are unique
#     512 for attr in attrs_unique:
#
# VariableNotFoundError: No files were found containing 'salt' in the 'woa13/01' experiment

# %%
plt.figure(figsize=(14,8))
clev = np.arange(-1,1.01,0.05)
land_50m = cft.NaturalEarthFeature('physical', 'land', '50m',
                                        edgecolor='black',
                                        facecolor='gray',linewidth=0.5)

ax1 = plt.subplot(2,2,1,projection=ccrs.Robinson(central_longitude=-100))
ax1.coastlines(resolution='50m')
ax1.add_feature(land_50m)
p1 = salt_anom_10.plot.contourf(cmap=cm.cm.balance,levels=clev,add_colorbar=False,transform=ccrs.PlateCarree())
plt.title('(a) ACCESS-OM2')

ax2 = plt.subplot(2,2,2,projection=ccrs.Robinson(central_longitude=-100))
ax2.coastlines(resolution='50m')
ax2.add_feature(land_50m)
p1 = salt_anom_025.plot.contourf(cmap=cm.cm.balance,levels=clev,add_colorbar=False,transform=ccrs.PlateCarree())
plt.title('(b) ACCESS-OM2-025')

ax3 = plt.subplot(2,2,3,projection=ccrs.Robinson(central_longitude=-100))
ax3.coastlines(resolution='50m')
ax3.add_feature(land_50m)
p1 = salt_anom_01.plot.contourf(cmap=cm.cm.balance,levels=clev,add_colorbar=False,transform=ccrs.PlateCarree())
plt.title('(c) ACCESS-OM2-01')

ax4 = plt.subplot(2,2,4,projection=ccrs.Robinson(central_longitude=-100))
ax4.coastlines(resolution='50m')
ax4.add_feature(land_50m)
p4 = salt_WOA13_01.plot.contourf(cmap=cm.cm.haline,levels=np.arange(32,36.01,0.1),add_colorbar=False,transform=ccrs.PlateCarree())
plt.title('(d) WOA13')

ax5 = plt.axes([0.92,0.52,0.01,0.33])
cb = plt.colorbar(p1,cax=ax5,orientation='vertical')
cb.ax.set_ylabel('SSS anomaly (g/kg)')

ax6 = plt.axes([0.92,0.13,0.01,0.33])
cb = plt.colorbar(p4,cax=ax6,orientation='vertical')
cb.ax.set_ylabel('SSS (g/kg)')

savefigure('global_sss_bias')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       8 ax1.coastlines(resolution='50m')
#       9 ax1.add_feature(land_50m)
# ---> 10 p1 = salt_anom_10.plot.contourf(cmap=cm.cm.balance,levels=clev,add_colorbar=False,transform=ccrs.PlateCarree())
#      11 plt.title('(a) ACCESS-OM2')
#      13 ax2 = plt.subplot(2,2,2,projection=ccrs.Robinson(central_longitude=-100))
#
# NameError: name 'salt_anom_10' is not defined
